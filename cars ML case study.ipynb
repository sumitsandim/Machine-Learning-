# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv('cars.csv')
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# 0            rwd           front   64.1    48.8        dohc          130
# 1            rwd           front   64.1    48.8        dohc          130
# 2            rwd           front   65.5    52.4        ohcv          152
# 3            fwd           front   66.2    54.3         ohc          109
# 4            4wd           front   66.4    54.3         ohc          136
# ..           ...             ...    ...     ...         ...          ...
# 200          rwd           front   68.9    55.5         ohc          141
# 201          rwd           front   68.8    55.5         ohc          141
# 202          rwd           front   68.9    55.5        ohcv          173
# 203          rwd           front   68.9    55.5         ohc          145
# 204          rwd           front   68.9    55.5         ohc          141
#
#     horsepower  city-mpg  highway-mpg  price
# 0          111        21           27  13495
# 1          111        21           27  16500
# 2          154        19           26  16500
# 3          102        24           30  13950
# 4          115        18           22  17450
# ..         ...       ...          ...    ...
# 200        114        23           28  16845
# 201        160        19           25  19045
# 202        134        18           23  21485
# 203        106        26           27  22470
# 204        114        19           25  22625
#
# [205 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# memory usage: 24.1+ KB

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
n_cols=df.select_dtypes(include=['int','float']).columns
n_cols
# Out:
# Index(['symboling', 'width', 'height', 'engine-size', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
c_cols=df.select_dtypes(include='O').columns
c_cols
# Out:
# Index(['normalized-losses', 'make', 'fuel-type', 'body-style', 'drive-wheels',
#        'engine-location', 'engine-type', 'horsepower'],
#       dtype='object')

# %%
sns.set()
plt.figure(figsize=(10,12))
count=1
for i in n_cols:
    plt.subplot(2,4,count)
    sns.distplot(df[i])
    count+=1
plt.show()

# %% [markdown]
# *  symboling range lies between -2 to 3
# * average symboling value is 0.8
# * Symboling of a car is slightly skewed
# * width range lies between 60 to 73
# * average width value is 65
# * The width of a car is normally distributed
# * the height range of cars lies between 47 to 60
# * The average height of car is 54
# * The height of cars has a minimal skewness
# * engine-size lies between 61 to 326
# * average engine-size is 127
# * The engine is rightly skewed

# %%
df.describe()
# Out:
#         symboling       width      height  engine-size    city-mpg  \
# count  205.000000  205.000000  205.000000   205.000000  205.000000
# mean     0.834146   65.907805   53.724878   126.907317   25.219512
# std      1.245307    2.145204    2.443522    41.642693    6.542142
# min     -2.000000   60.300000   47.800000    61.000000   13.000000
# 25%      0.000000   64.100000   52.000000    97.000000   19.000000
# 50%      1.000000   65.500000   54.100000   120.000000   24.000000
# 75%      2.000000   66.900000   55.500000   141.000000   30.000000
# max      3.000000   72.300000   59.800000   326.000000   49.000000
#
#        highway-mpg         price
# count   205.000000    205.000000
# mean     30.751220  13227.478049
# std       6.886443   7902.651615
# min      16.000000   5118.000000
# 25%      25.000000   7788.000000
# 50%      30.000000  10345.000000
# 75%      34.000000  16500.000000
# max      54.000000  45400.000000

# %%
plt.figure(figsize=(16,8))
count=1
for i in c_cols:
    plt.subplot(2,4,count)
    plt.xticks(rotation=90)
    sns.countplot(df[i])
    count+=1
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
plt.figure(figsize=(20,25))
count=1
for i in c_cols:
    plt.subplot(2,4,count)
    plt.xticks(rotation=90)
    sns.barplot(data=df,x='price',y=i)
    count+=1
plt.show()

# %%
df['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,x='price',y='make')
# Out:
# <AxesSubplot:xlabel='price', ylabel='make'>

# %%
df.loc[(df['make']=='toyota')&(df['price']>15000)]
# Out:
#      symboling normalized-losses    make fuel-type   body-style drive-wheels  \
# 172          2               134  toyota       gas  convertible          rwd
# 178          3               197  toyota       gas    hatchback          rwd
# 179          3               197  toyota       gas    hatchback          rwd
# 180         -1                90  toyota       gas        sedan          rwd
# 181         -1                 ?  toyota       gas        wagon          rwd
#
#     engine-location  width  height engine-type  engine-size horsepower  \
# 172           front   65.6    53.0         ohc          146        116
# 178           front   67.7    52.0        dohc          171        161
# 179           front   67.7    52.0        dohc          171        161
# 180           front   66.5    54.1        dohc          171        156
# 181           front   66.5    54.1        dohc          161        156
#
#      city-mpg  highway-mpg  price
# 172        24           30  17669
# 178        20           24  16558
# 179        19           24  15998
# 180        20           24  15690
# 181        19           24  15750

# %%
df.drop(index=[172,178,179,180,181],inplace=True)

# %%
df.loc[(df['make']=='plymouth')&(df['price']>10000)]
# Out:
#      symboling normalized-losses      make fuel-type body-style drive-wheels  \
# 124          3                 ?  plymouth       gas  hatchback          rwd
#
#     engine-location  width  height engine-type  engine-size horsepower  \
# 124           front   66.3    50.2         ohc          156        145
#
#      city-mpg  highway-mpg  price
# 124        19           24  12764

# %%
df.drop(index=124,inplace=True)

# %%
df.loc[(df['make']=='mitsubishi')&(df['price']>14000)]
# Out:
#     symboling normalized-losses        make fuel-type body-style drive-wheels  \
# 83          3                 ?  mitsubishi       gas  hatchback          fwd
# 84          3                 ?  mitsubishi       gas  hatchback          fwd
#
#    engine-location  width  height engine-type  engine-size horsepower  \
# 83           front   66.3    50.2         ohc          156        145
# 84           front   66.3    50.2         ohc          156        145
#
#     city-mpg  highway-mpg  price
# 83        19           24  14869
# 84        19           24  14489

# %%
df.drop(index=[83,84],inplace=True)

# %%
df.loc[(df['make']=='isuzu')&(df['price']>20000)]
# Out:
#     symboling normalized-losses   make fuel-type body-style drive-wheels  \
# 45          0                 ?  isuzu       gas      sedan          fwd
#
#    engine-location  width  height engine-type  engine-size horsepower  \
# 45           front   63.6    52.0         ohc           90         70
#
#     city-mpg  highway-mpg  price
# 45        38           43  23000

# %%
df.drop([45],inplace=True)

# %%
df.loc[(df['make']=='honda')&(df['price']>12000)]
# Out:
#     symboling normalized-losses   make fuel-type body-style drive-wheels  \
# 41          0                85  honda       gas      sedan          fwd
#
#    engine-location  width  height engine-type  engine-size horsepower  \
# 41           front   65.2    54.1         ohc          110        101
#
#     city-mpg  highway-mpg  price
# 41        24           28  12945

# %%
df.drop([41],inplace=True)

# %%
df.loc[(df['make']=='dodge')&(df['price']>12000)]
# Out:
#     symboling normalized-losses   make fuel-type body-style drive-wheels  \
# 29          3               145  dodge       gas  hatchback          fwd
#
#    engine-location  width  height engine-type  engine-size horsepower  \
# 29           front   66.3    50.2         ohc          156        145
#
#     city-mpg  highway-mpg  price
# 29        19           24  12964

# %%
df.drop([29],inplace=True)

# %% [markdown]
# ## Handling categorical columns

# %%
df['normalized-losses'].unique()
# Out:
# array(['?', '164', '158', '192', '188', '121', '98', '81', '118', '148',
#        '110', '137', '101', '78', '106', '85', '107', '145', '104', '113',
#        '150', '129', '115', '93', '142', '161', '153', '125', '128',
#        '122', '103', '168', '108', '194', '231', '119', '154', '74',
#        '186', '83', '102', '89', '87', '77', '91', '134', '65', '94',
#        '256', '95'], dtype=object)

# %%
df['normalized-losses']=df['normalized-losses'].replace('?',np.nan)

# %%
df.isnull().sum()/len(df)*100
# Out:
# symboling             0.000000
# normalized-losses    18.556701
# make                  0.000000
# fuel-type             0.000000
# body-style            0.000000
# drive-wheels          0.000000
# engine-location       0.000000
# width                 0.000000
# height                0.000000
# engine-type           0.000000
# engine-size           0.000000
# horsepower            0.000000
# city-mpg              0.000000
# highway-mpg           0.000000
# price                 0.000000
# dtype: float64

# %%
df['normalized-losses']=df['normalized-losses'].astype(float)

# %%
df['normalized-losses']=df['normalized-losses'].fillna(df['normalized-losses'].mean())

# %%
df['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
df['fuel-type'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
for i in c_cols:
    print('_'*60)
    print(i)
    print(df[i].unique())
# Out:
# ____________________________________________________________
# normalized-losses
# [121.26582278 164.         158.         192.         188.
#  121.          98.          81.         118.         148.
#  110.         137.         101.          78.         106.
#   85.         107.         145.         104.         113.
#  150.         129.         115.          93.         142.
#  161.         153.         125.         128.         122.
#  103.         168.         108.         194.         231.
#  119.         154.          74.         186.          83.
#  102.          89.          87.          77.          91.
#  134.          65.          94.         256.          95.        ]
# ____________________________________________________________
# make
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
# ____________________________________________________________
# fuel-type
# ['gas' 'diesel']
# ____________________________________________________________
# body-style
# ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# ____________________________________________________________
# drive-wheels
# ['rwd' 'fwd' '4wd']
# ____________________________________________________________
# engine-location
# ['front' 'rear']
# ____________________________________________________________
# engine-type
# ['dohc' 'ohcv' 'ohc' 'l' 'rotor' 'ohcf' 'dohcv']
# ____________________________________________________________
# horsepower
# ['111' '154' '102' '115' '110' '140' '160' '101' '121' '182' '48' '70'
#  '68' '88' '58' '76' '60' '86' '100' '78' '90' '176' '262' '135' '84' '64'
#  '120' '72' '123' '155' '184' '175' '116' '145' '69' '55' '97' '152' '200'
#  '95' '142' '143' '207' '288' '?' '73' '82' '94' '62' '56' '112' '92' '52'
#  '85' '114' '162' '134' '106']

# %%
df['horsepower']=df['horsepower'].replace('?',np.nan)

# %%
df.dropna(inplace=True)

# %%
df['horsepower']=df['horsepower'].astype(float)

# %%
df['horsepower'].unique()
# Out:
# array([111., 154., 102., 115., 110., 140., 160., 101., 121., 182.,  48.,
#         70.,  68.,  88.,  58.,  76.,  60.,  86., 100.,  78.,  90., 176.,
#        262., 135.,  84.,  64., 120.,  72., 123., 155., 184., 175., 116.,
#        145.,  69.,  55.,  97., 152., 200.,  95., 142., 143., 207., 288.,
#         73.,  82.,  94.,  62.,  56., 112.,  92.,  52.,  85., 114., 162.,
#        134., 106.])

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type   body-style  \
# 0          3         121.265823  alfa-romero       gas  convertible
# 1          3         121.265823  alfa-romero       gas  convertible
# 2          1         121.265823  alfa-romero       gas    hatchback
# 3          2         164.000000         audi       gas        sedan
# 4          2         164.000000         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#    horsepower  city-mpg  highway-mpg  price
# 0       111.0        21           27  13495
# 1       111.0        21           27  16500
# 2       154.0        19           26  16500
# 3       102.0        24           30  13950
# 4       115.0        18           22  17450

# %%
le=LabelEncoder()

# %%
co_cols=df.select_dtypes(include='O').columns
co_cols
# Out:
# Index(['make', 'fuel-type', 'body-style', 'drive-wheels', 'engine-location',
#        'engine-type'],
#       dtype='object')

# %%
for i in co_cols:
    df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#      symboling  normalized-losses  make  fuel-type  body-style  drive-wheels  \
# 0            3         121.265823     0          1           0             2
# 1            3         121.265823     0          1           0             2
# 2            1         121.265823     0          1           2             2
# 3            2         164.000000     1          1           3             1
# 4            2         164.000000     1          1           3             0
# ..         ...                ...   ...        ...         ...           ...
# 187         -1          95.000000    20          1           3             2
# 188         -1          95.000000    20          1           3             2
# 189         -1          95.000000    20          1           3             2
# 190         -1          95.000000    20          0           3             2
# 191         -1          95.000000    20          1           3             2
#
#      engine-location  width  height  engine-type  engine-size  horsepower  \
# 0                  0   64.1    48.8            0          130       111.0
# 1                  0   64.1    48.8            0          130       111.0
# 2                  0   65.5    52.4            5          152       154.0
# 3                  0   66.2    54.3            3          109       102.0
# 4                  0   66.4    54.3            3          136       115.0
# ..               ...    ...     ...          ...          ...         ...
# 187                0   68.9    55.5            3          141       114.0
# 188                0   68.8    55.5            3          141       160.0
# 189                0   68.9    55.5            5          173       134.0
# 190                0   68.9    55.5            3          145       106.0
# 191                0   68.9    55.5            3          141       114.0
#
#      city-mpg  highway-mpg  price
# 0          21           27  13495
# 1          21           27  16500
# 2          19           26  16500
# 3          24           30  13950
# 4          18           22  17450
# ..        ...          ...    ...
# 187        23           28  16845
# 188        19           25  19045
# 189        18           23  21485
# 190        26           27  22470
# 191        19           25  22625
#
# [192 rows x 15 columns]

# %%
#independent variable
X=df.iloc[:,:-1]
#dependent variable
y=df.iloc[:,-1]

# %%
X
# Out:
#      symboling  normalized-losses  make  fuel-type  body-style  drive-wheels  \
# 0            3         121.265823     0          1           0             2
# 1            3         121.265823     0          1           0             2
# 2            1         121.265823     0          1           2             2
# 3            2         164.000000     1          1           3             1
# 4            2         164.000000     1          1           3             0
# ..         ...                ...   ...        ...         ...           ...
# 187         -1          95.000000    20          1           3             2
# 188         -1          95.000000    20          1           3             2
# 189         -1          95.000000    20          1           3             2
# 190         -1          95.000000    20          0           3             2
# 191         -1          95.000000    20          1           3             2
#
#      engine-location  width  height  engine-type  engine-size  horsepower  \
# 0                  0   64.1    48.8            0          130       111.0
# 1                  0   64.1    48.8            0          130       111.0
# 2                  0   65.5    52.4            5          152       154.0
# 3                  0   66.2    54.3            3          109       102.0
# 4                  0   66.4    54.3            3          136       115.0
# ..               ...    ...     ...          ...          ...         ...
# 187                0   68.9    55.5            3          141       114.0
# 188                0   68.8    55.5            3          141       160.0
# 189                0   68.9    55.5            5          173       134.0
# 190                0   68.9    55.5            3          145       106.0
# 191                0   68.9    55.5            3          141       114.0
#
#      city-mpg  highway-mpg
# 0          21           27
# 1          21           27
# 2          19           26
# 3          24           30
# 4          18           22
# ..        ...          ...
# 187        23           28
# 188        19           25
# 189        18           23
# 190        26           27
# 191        19           25
#
# [192 rows x 14 columns]

# %%
y
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 187    16845
# 188    19045
# 189    21485
# 190    22470
# 191    22625
# Name: price, Length: 192, dtype: int64

# %%
#Split  dataset into train and test data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=123)

# %%
X_train.shape
# Out:
# (153, 14)

# %%
X_test.shape
# Out:
# (39, 14)

# %%
y_train.shape
# Out:
# (153,)

# %%
y_test.shape
# Out:
# (39,)

# %%
import sklearn

# %%
from sklearn .linear_model import LinearRegression

# %%
car=LinearRegression()

# %%
car.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred=car.predict(X_train)
y_test_pred=car.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error
def model_performance(y_actual,y_pred):
    r2=r2_score(y_actual,y_pred)
    RMSE=np.sqrt(mean_squared_error(y_actual,y_pred))
    print("r2_score:{},RMSE :{}".format(round(r2,2),round(RMSE,2)))

# %%
print("Train Performance")
model_performance(y_train,y_train_pred)
print("Train Performance")
model_performance(y_test,y_test_pred)
# Out:
# Train Performance
# r2_score:0.86,RMSE :3126.71
# Train Performance
# r2_score:0.87,RMSE :2357.06

# %%
#y-intercept
car.intercept_
# Out:
# -47134.28340213783

# %%
#coefficient
car.coef_
# Out:
# array([ 2.11056044e+02, -4.06866668e+00, -2.01209290e+02, -8.69746666e+02,
#         1.27100326e+01,  2.41775469e+03,  1.46829881e+04,  6.54205129e+02,
#         2.38256934e+02, -3.33147265e+00,  8.82876000e+01,  6.83390621e-01,
#         1.72184988e+02, -3.64681827e+02])

# %%
pd.DataFrame(car.coef_,X.columns,columns=["coef"])
# Out:
#                            coef
# symboling            211.056044
# normalized-losses     -4.068667
# make                -201.209290
# fuel-type           -869.746666
# body-style            12.710033
# drive-wheels        2417.754691
# engine-location    14682.988093
# width                654.205129
# height               238.256934
# engine-type           -3.331473
# engine-size           88.287600
# horsepower             0.683391
# city-mpg             172.184988
# highway-mpg         -364.681827

# %%
from sklearn.linear_model import Ridge,Lasso

# %%
l1=Lasso(alpha=9)
l1.fit(X_train,y_train)
y_pred_train=l1.predict(X_train)
y_pred_test=l1.predict(X_test)

# %%
print("Train perfomance")
model_performance(y_train,y_pred_train)
print("Test perfomance")
model_performance(y_test,y_pred_test)
# Out:
# Train perfomance
# r2_score:0.86,RMSE :3127.83
# Test perfomance
# r2_score:0.88,RMSE :2344.18

# %%
for i in range(1,250):
    l2=Ridge(i)
    l2.fit(X_train,y_train)
    y_pred_train=l2.predict(X_train)
    y_pred_test=l2.predict(X_test)
    print(f"{i}:{l2.score(X_test,y_test)}")
# Out:
# 1:0.8832711499797801
# 2:0.8869710349976789
# 3:0.8891041287920367
# 4:0.8905871862080419
# 5:0.8917246917399401
# 6:0.8926462269871148
# 7:0.8934174257722284
# 8:0.8940761377398083
# 9:0.8946464579690545
# 10:0.8951449293924817
# 11:0.8955835831233815
# 12:0.8959715605904187
# 13:0.8963160430881933
# 14:0.8966228180596052
# 15:0.8968966427907912
# 16:0.8971414889102535
# 17:0.8973607133572408
# 18:0.8975571820392958
# 19:0.8977333618858663
# 20:0.8978913910741064
# 21:0.898033133726564
# 22:0.8981602232704045
# 23:0.8982740973256091
# 24:0.89837602613633
# 25:0.8984671359938715
# 26:0.8985484287151724
# 27:0.8986207979731432
# 28:0.8986850430851252
# 29:0.8987418807280378
# 30:0.8987919549472481
# 31:0.8988358457501188
# 32:0.8988740765173378
# 33:0.8989071204205604
# 34:0.8989354060001541
# 35:0.8989593220294182
# 36:0.898979221769874
# 37:0.8989954267046893
# 38:0.8990082298231442
# 39:0.8990178985174812
# 40:0.8990246771440022
# 41:0.8990287892924536
# 42:0.8990304398012129
# 43:0.8990298165504128
# 44:0.8990270920605362
# 45:0.8990224249202368
# 46:0.8990159610638725
# 47:0.8990078349165089
# 48:0.8989981704218065
# 49:0.8989870819662147
# 50:0.898974675211183
# 51:0.8989610478436252
# 172:0.8960981369606991
# 173:0.8960787763586617
# 174:0.8960595111758316
# 175:0.8960403409566465
# 176:0.8960212652433651
# 177:0.8960022835763038
# 178:0.8959833954940691
# 179:0.8959646005337718
# 180:0.8959458982312358
# 181:0.8959272881211944
# 182:0.8959087697374798
# 183:0.8958903426131987
# 184:0.8958720062809055
# 185:0.8958537602727612
# 186:0.8958356041206887
# 187:0.8958175373565174
# 188:0.8957995595121246
# 189:0.8957816701195658
# 190:0.8957638687111991
# 191:0.8957461548198085
# 192:0.8957285279787135
# 193:0.8957109877218772
# 194:0.8956935335840106
# 195:0.8956761651006679
# 196:0.8956588818083376
# 197:0.8956416832445321
# 198:0.8956245689478679
# 199:0.8956075384581459
# 200:0.8955905913164246
# 201:0.8955737270650893
# 202:0.895556945247921
# 203:0.8955402454101578
# 204:0.8955236270985528
# 205:0.8955070898614325
# 206:0.8954906332487491
# 207:0.8954742568121297
# 208:0.8954579601049226
# 209:0.8954417426822434
# 210:0.8954256041010151
# 211:0.895409543920008
# 212:0.8953935616998748
# 213:0.8953776570031873
# 214:0.8953618293944664
# 215:0.8953460784402125
# 216:0.8953304037089341
# 217:0.895314804771175
# 218:0.895299281199534
# 219:0.8952838325686938
# 220:0.8952684584554359
# 221:0.8952531584386634
# 222:0.8952379320994176
# 223:0.8952227790208931
# 224:0.8952076987884543
# 225:0.8951926909896479
# 226:0.8951777552142154
# 227:0.8951628910541025
# 228:0.8951480981034715
# 229:0.8951333759587078
# 230:0.8951187242184281
# 231:0.8951041424834876
# 232:0.8950896303569841
# 233:0.8950751874442643
# 234:0.8950608133529259
# 235:0.8950465076928225
# 236:0.8950322700760637
# 237:0.8950181001170171
# 238:0.8950039974323105
# 239:0.8949899616408286
# 240:0.8949759923637153
# 241:0.8949620892243701
# 242:0.8949482518484482
# 243:0.8949344798638559
# 244:0.894920772900748
# 245:0.8949071305915255
# 246:0.8948935525708299
# 247:0.8948800384755385
# 248:0.8948665879447613
# 249:0.8948532006198328

# %%
for i in range(1,250):
    l1=Lasso(i)
    l1.fit(X_train,y_train)
    y_pred_train=l1.predict(X_train)
    y_pred_test=l1.predict(X_test)
    print(f"{i}:{l1.score(X_test,y_test)}")
# Out:
# 1:0.8741043996300901
# 2:0.8742897635282111
# 3:0.8744300960441276
# 4:0.8745694967922714
# 5:0.874707932796939
# 6:0.8748455514784489
# 7:0.8749821047530212
# 8:0.8751179347981992
# 9:0.875252635719686
# 10:0.8753868497058719
# 11:0.8755227067563195
# 12:0.8756574477109398
# 13:0.8757912267344121
# 14:0.8759240460805111
# 15:0.8760559036289449
# 16:0.8761868004417976
# 17:0.8763167373859719
# 18:0.8764455124713456
# 19:0.8765735217264812
# 20:0.8767005706411547
# 21:0.8768264460632226
# 22:0.8769515671425643
# 23:0.8770755144250535
# 24:0.8771987177863518
# 25:0.8773207391919949
# 26:0.8774420164121303
# 27:0.8775621063755192
# 28:0.8776814574800175
# 29:0.8777996145358214
# 30:0.8779170298807935
# 31:0.878033248501688
# 32:0.8781487381113701
# 153:0.8868698885451944
# 154:0.8869177945111487
# 155:0.8869649990944983
# 156:0.8870115040793153
# 157:0.8870573094655992
# 158:0.88710241525335
# 159:0.8871468214425676
# 160:0.8871905280332526
# 161:0.8872335305054037
# 162:0.887275832961081
# 163:0.8873174357689639
# 164:0.8873583414880767
# 165:0.8873985518323407
# 166:0.8874380625960228
# 167:0.8874768737791227
# 168:0.8875149853816404
# 169:0.8875523974035763
# 170:0.8875891098449302
# 171:0.8876251223854434
# 172:0.887660435300424
# 173:0.8876950486359442
# 174:0.8877289623920034
# 175:0.8877621765686019
# 176:0.8877946911657398
# 177:0.8878265068547783
# 178:0.8878579945447209
# 179:0.8878884128387639
# 180:0.8879181315522456
# 181:0.887947150685167
# 182:0.8879754702375279
# 183:0.8880030902093276
# 184:0.8880300106005666
# 185:0.8880562314112452
# 186:0.8880817526413629
# 187:0.8881065742909199
# 188:0.8881306963599161
# 189:0.8881541188483516
# 190:0.8881768417562266
# 191:0.8881988650835405
# 192:0.888220188830294
# 193:0.8882408134372356
# 194:0.888260737616141
# 195:0.888279953438398
# 196:0.8882984432511138
# 197:0.888317982492453
# 198:0.8883687554363472
# 199:0.8884189277862197
# 200:0.8884687812553523
# 201:0.8885183158437449
# 202:0.8885675315513972
# 203:0.8886164283783091
# 204:0.888665009353658
# 205:0.8887132729939973
# 206:0.8887612177508761
# 207:0.888808843624294
# 208:0.8888561505704108
# 209:0.8889031385524447
# 210:0.8889498076509025
# 211:0.8889961578657835
# 212:0.8890421891970883
# 213:0.8890879016448167
# 214:0.8891332970973387
# 215:0.8891783747762227
# 216:0.8892231335890782
# 217:0.8892675735176834
# 218:0.8893116945606123
# 219:0.8893554967178648
# 220:0.8893989799894406
# 221:0.8894421443753404
# 222:0.8894849898755638
# 223:0.8895275164901105
# 224:0.8895697242189811
# 225:0.889611613062175
# 226:0.8896531830196924
# 227:0.8896944340915334
# 228:0.8897353662776982
# 229:0.8897759798571646
# 230:0.8898162761034029
# 231:0.8898562534203066
# 232:0.8898959117960001
# 233:0.8899344781009276
# 234:0.8899734952013502
# 235:0.8900121934227381
# 236:0.8900505727268813
# 237:0.8900886331370678
# 238:0.8901263746683492
# 239:0.8901637973207254
# 240:0.8902009010941961
# 241:0.8902376859887617
# 242:0.8902741520044223
# 243:0.8903102991411775
# 244:0.8903461273990273
# 245:0.8903816367779722
# 246:0.8904168272780116
# 247:0.8904516988991461
# 248:0.8904862516413751
# 249:0.8905204857372601

# %%
from sklearn.model_selection import cross_val_score

# %%
l1_score=cross_val_score(l1,X,y,scoring="r2",cv=5)

# %%
l1_score
# Out:
# array([0.81164262, 0.88515783, 0.10540992, 0.50070864, 0.36308505])

# %%
mean_l1_score=np.mean(l1_score)
mean_l1_score
# Out:
# 0.5332008114677513

# %%
l2_score=cross_val_score(l2,X,y,scoring="r2",cv=5)

# %%
l2_score
# Out:
# array([0.81135827, 0.88759083, 0.11087345, 0.60741906, 0.40939064])

# %%
mean_l2_score=np.mean(l2_score)
mean_l2_score
# Out:
# 0.5653264500006521
